# %%
import pandas as pd
import numpy as np

# %%
artistas = pd.read_csv('Datos Pares/Artistas.csv')
eventos = pd.read_csv('Datos Pares/Evento.csv')
productoras = pd.read_csv('Datos Pares/Productoras.csv')
recintos = pd.read_csv('Datos Pares/Recinto.csv')
entradas = pd.read_csv('Datos Pares/Entradas.csv')

# %%
artistas.rename(columns = {'Nombre artistico':'nombre_artistico', 'Nº contacto':'contacto_artista'}, inplace = True)
entradas.rename(columns = {'Evento':'nombre_evento', 'numero asiento':'numero_asiento'}, inplace = True)
recintos.rename(columns = {'Nombre':'nombre_recinto', 'Ciudad':'ciudad', 'Pais':'pais', 'Capacidad':'capacidad'}, inplace = True)
productoras.rename(columns = {'Nombre':'nombre_productora', 'País':'pais', 'Inicio actividades':'inicio_actividades', 'Nº contacto':'contacto_productora'}, inplace = True)
eventos.rename(columns = {'Nombre':'nombre_evento', 'Recinto':'recinto', 'Fecha de incio':'fecha_inicio', 'Fecha de termino':'fecha_termino', 'Artista':'artista', 'Productora':'productora'}, inplace = True)

# %%
artistas.drop_duplicates(inplace=True, ignore_index=True)
eventos.drop_duplicates(inplace=True, ignore_index=True)
productoras.drop_duplicates(inplace=True, ignore_index=True)
recintos.drop_duplicates(inplace=True, ignore_index=True)
entradas.drop_duplicates(inplace=True, ignore_index=True)

# %%
productoras.drop_duplicates(subset=['nombre_productora'], inplace=True, ignore_index=True)
recintos.drop_duplicates(subset=['nombre_recinto'], inplace=True, ignore_index=True)

# %%
artistas['nombre_artistico'] = artistas['nombre_artistico'].str.strip()

eventos['nombre_evento'] = eventos['nombre_evento'].str.strip()
eventos['recinto'] = eventos['recinto'].str.strip()
eventos['artista'] = eventos['artista'].str.strip()
eventos['productora'] = eventos['productora'].str.strip()

productoras['nombre_productora'] = productoras['nombre_productora'].str.strip()
productoras['pais'] = productoras['pais'].str.strip()

recintos['nombre_recinto'] = recintos['nombre_recinto'].str.strip()
recintos['ciudad'] = recintos['ciudad'].str.strip()
recintos['pais'] = recintos['pais'].str.strip()

entradas['nombre_evento'] = entradas['nombre_evento'].str.strip()
entradas['categoria'] = entradas['categoria'].str.strip()
entradas['numero_asiento'] = entradas['numero_asiento'].str.strip()

# %%
eventos.index.name = 'id_evento'
artistas.index.name = 'id_artista'
productoras.index.name = 'id_productora'
recintos.index.name = 'id_recinto'
entradas.index.name = 'id_entrada'

# %%
entradas["precio"] = entradas["precio"].str.replace(",","")
entradas["precio"] = entradas["precio"].str.replace(".","")
eventos["fecha_inicio"] = eventos["fecha_inicio"].str.replace("-","/")
eventos["fecha_termino"] = eventos["fecha_termino"].str.replace("-","/")
productoras["inicio_actividades"] = productoras["inicio_actividades"].str.replace("-","/")
# Out:
# C:\Users\beagg\AppData\Local\Temp\ipykernel_2328\1462102617.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   entradas["precio"] = entradas["precio"].str.replace(".","")

# %%
eventos.fecha_inicio = eventos.fecha_inicio.replace({'30/2/':'28/02/'}, regex=True)
eventos.fecha_inicio = eventos.fecha_inicio.replace({'30/02/':'28/02/'}, regex=True)

eventos.fecha_inicio = eventos.fecha_inicio.replace({'31/04/':'30/04/'}, regex=True)
eventos.fecha_inicio = eventos.fecha_inicio.replace({'31/4/':'30/04/'}, regex=True)

eventos.fecha_termino = eventos.fecha_termino.replace({'30/02/':'28/02/'}, regex=True)
eventos.fecha_termino = eventos.fecha_termino.replace({'30/2/':'28/02/'}, regex=True)

eventos.fecha_termino = eventos.fecha_termino.replace({'31/04/':'30/04/'}, regex=True)
eventos.fecha_termino = eventos.fecha_termino.replace({'31/4/':'30/04/'}, regex=True)

productoras.inicio_actividades = productoras.inicio_actividades.replace({'30/2/':'28/02/'}, regex=True)
productoras.inicio_actividades = productoras.inicio_actividades.replace({'30/02/':'28/02/'}, regex=True)
productoras.inicio_actividades = productoras.inicio_actividades.replace({'31/04/':'30/04/'}, regex=True)
productoras.productoras = productoras.inicio_actividades.replace({'31/4/':'30/04/'}, regex=True)
# Out:
# C:\Users\beagg\AppData\Local\Temp\ipykernel_2328\2337790061.py:16: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   productoras.productoras = productoras.inicio_actividades.replace({'31/4/':'30/04/'}, regex=True)

# %%
eventos['fecha_inicio'] =pd.to_datetime(eventos.fecha_inicio)
eventos['fecha_termino'] =pd.to_datetime(eventos.fecha_termino)
productoras['inicio_actividades'] =pd.to_datetime(productoras.inicio_actividades)
# Out:
# C:\Users\beagg\AppData\Local\Temp\ipykernel_2328\713017843.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   eventos['fecha_inicio'] =pd.to_datetime(eventos.fecha_inicio)
# C:\Users\beagg\AppData\Local\Temp\ipykernel_2328\713017843.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   eventos['fecha_termino'] =pd.to_datetime(eventos.fecha_termino)
# C:\Users\beagg\AppData\Local\Temp\ipykernel_2328\713017843.py:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   productoras['inicio_actividades'] =pd.to_datetime(productoras.inicio_actividades)

# %%
eventos_unicos = eventos[['nombre_evento','recinto','fecha_inicio','fecha_termino','productora']]

# %%
eventos_unicos.drop_duplicates(inplace=True, ignore_index=True)
# Out:
# C:\Users\beagg\AppData\Local\Temp\ipykernel_2328\1243864138.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eventos_unicos.drop_duplicates(inplace=True, ignore_index=True)

# %%
eventos_unicos.index.name = 'id_evento'

# %%
eventos_unicos.insert(0, 'id_evento2', range(1, 201))

# %%
eventos
# Out:
#                      nombre_evento               recinto fecha_inicio  \
# id_evento
# 0                      Rio Concert              Vivo Rio   2016-02-26
# 1                        Mil Rosas   Mercedes-Benz Arena   2022-11-29
# 2                  Bachata en vivo          Irving Plaza   2020-11-05
# 3             Como si no importara    Arena Ludwingsburg   2021-01-23
# 4                        Epic Show        Freiheitshalle   2022-04-03
# ...                            ...                   ...          ...
# 228                       Gowlding            Sala Apolo   2019-07-03
# 229                    Rio Concert              Vivo Rio   2016-02-26
# 230        Michael Jackson Tribute   Cupula Multiespacio   2017-11-13
# 231                     The Misery           Spark Arena   2020-10-27
# 232                         El J23  Canadian Tire Centre   2020-10-07
#
#           fecha_termino                artista                 productora
# id_evento
# 0            2016-02-29   Francisca Valenzuela                Agencia 360
# 1            2022-11-29   La Oreja de Van Gogh  Eventveranstalter Hamburg
# 2            2020-11-05           Prince Royce                 The Imagos
# 3            2021-01-23                 Emilia               fullevent.de
# 4            2022-04-03  The Martinez Brothers                 B+D Events
# ...                 ...                    ...                        ...
# 228          2019-07-03         Ellie Gowlding                Live Nation
# 229          2016-02-29          Maria Becerra                Agencia 360
# 230          2017-11-15        Michael Jackson         Time for fun (t4f)
# 231          2020-10-27        Imagine Dragons   Queenstown Event Company
# 232          2020-10-07              Jordan 23         Mayam Producciones
#
# [233 rows x 6 columns]

# %%
eventos_unicos
# Out:
#            id_evento2            nombre_evento               recinto  \
# id_evento
# 0                   1              Rio Concert              Vivo Rio
# 1                   2                Mil Rosas   Mercedes-Benz Arena
# 2                   3          Bachata en vivo          Irving Plaza
# 3                   4     Como si no importara    Arena Ludwingsburg
# 4                   5                Epic Show        Freiheitshalle
# ...               ...                      ...                   ...
# 195               196          Dangerous Woman           Niceto Club
# 196               197                 Gowlding            Sala Apolo
# 197               198  Michael Jackson Tribute   Cupula Multiespacio
# 198               199               The Misery           Spark Arena
# 199               200                   El J23  Canadian Tire Centre
#
#           fecha_inicio fecha_termino                 productora
# id_evento
# 0           2016-02-26    2016-02-29                Agencia 360
# 1           2022-11-29    2022-11-29  Eventveranstalter Hamburg
# 2           2020-11-05    2020-11-05                 The Imagos
# 3           2021-01-23    2021-01-23               fullevent.de
# 4           2022-04-03    2022-04-03                 B+D Events
# ...                ...           ...                        ...
# 195         2021-07-22    2021-07-22         Ramasso Productora
# 196         2019-07-03    2019-07-03                Live Nation
# 197         2017-11-13    2017-11-15         Time for fun (t4f)
# 198         2020-10-27    2020-10-27   Queenstown Event Company
# 199         2020-10-07    2020-10-07         Mayam Producciones
#
# [200 rows x 6 columns]

# %%
eventitos = eventos[['nombre_evento','fecha_inicio','artista', 'recinto']]

# %%
eventitos
eventos_fixed = pd.merge(eventos_unicos, eventitos, on=['nombre_evento','fecha_inicio','recinto'])

# %%
eventos_fixed.index.name = 'id_evento'

# %%
eventitos
# Out:
#                      nombre_evento fecha_inicio                artista  \
# id_evento
# 0                      Rio Concert   2016-02-26   Francisca Valenzuela
# 1                        Mil Rosas   2022-11-29   La Oreja de Van Gogh
# 2                  Bachata en vivo   2020-11-05           Prince Royce
# 3             Como si no importara   2021-01-23                 Emilia
# 4                        Epic Show   2022-04-03  The Martinez Brothers
# ...                            ...          ...                    ...
# 228                       Gowlding   2019-07-03         Ellie Gowlding
# 229                    Rio Concert   2016-02-26          Maria Becerra
# 230        Michael Jackson Tribute   2017-11-13        Michael Jackson
# 231                     The Misery   2020-10-27        Imagine Dragons
# 232                         El J23   2020-10-07              Jordan 23
#
#                         recinto
# id_evento
# 0                      Vivo Rio
# 1           Mercedes-Benz Arena
# 2                  Irving Plaza
# 3            Arena Ludwingsburg
# 4                Freiheitshalle
# ...                         ...
# 228                  Sala Apolo
# 229                    Vivo Rio
# 230         Cupula Multiespacio
# 231                 Spark Arena
# 232        Canadian Tire Centre
#
# [233 rows x 4 columns]

# %%
eventos_fixed
# Out:
#            id_evento2            nombre_evento               recinto  \
# id_evento
# 0                   1              Rio Concert              Vivo Rio
# 1                   1              Rio Concert              Vivo Rio
# 2                   1              Rio Concert              Vivo Rio
# 3                   1              Rio Concert              Vivo Rio
# 4                   1              Rio Concert              Vivo Rio
# ...               ...                      ...                   ...
# 228               196          Dangerous Woman           Niceto Club
# 229               197                 Gowlding            Sala Apolo
# 230               198  Michael Jackson Tribute   Cupula Multiespacio
# 231               199               The Misery           Spark Arena
# 232               200                   El J23  Canadian Tire Centre
#
#           fecha_inicio fecha_termino                productora  \
# id_evento
# 0           2016-02-26    2016-02-29               Agencia 360
# 1           2016-02-26    2016-02-29               Agencia 360
# 2           2016-02-26    2016-02-29               Agencia 360
# 3           2016-02-26    2016-02-29               Agencia 360
# 4           2016-02-26    2016-02-29               Agencia 360
# ...                ...           ...                       ...
# 228         2021-07-22    2021-07-22        Ramasso Productora
# 229         2019-07-03    2019-07-03               Live Nation
# 230         2017-11-13    2017-11-15        Time for fun (t4f)
# 231         2020-10-27    2020-10-27  Queenstown Event Company
# 232         2020-10-07    2020-10-07        Mayam Producciones
#
#                         artista
# id_evento
# 0          Francisca Valenzuela
# 1                      Anuel AA
# 2                 Justin Bieber
# 3                         Drake
# 4                     Bad Bunny
# ...                         ...
# 228               Ariana Grande
# 229              Ellie Gowlding
# 230             Michael Jackson
# 231             Imagine Dragons
# 232                   Jordan 23
#
# [233 rows x 7 columns]

# %%
# lugares = recintos[['ciudad', 'pais']]
# lugares

# %%
# lugares.drop_duplicates(inplace=True, ignore_index=True)

# %%
# recintos = recintos[['nombre_recinto', 'ciudad', 'capacidad']]
# recintos

# %%
# acceder_entrada = entradas[['nombre_evento']]
# acceder_entrada

# %%
# acceder_evento = eventos[['nombre_evento']]
# acceder_evento

# %%
# entradas['precio'] = entradas['precio'].str.strip()

# %%
# artistas
# eventos
#productoras
# recintos
# entradas
artistas.to_csv('artistas_procesados.csv',encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [29], in <cell line: 6>()
#       1 # artistas
#       2 # eventos
#       3 #productoras
#       4 # recintos
#       5 # entradas
# ----> 6 artistas.to_csv('artistas_procesados.csv',encoding='utf-8')
#
# File c:\users\beagg\appdata\local\programs\python\python38\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\users\beagg\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
#    3713     header=header,
#    (...)
#    3717     decimal=decimal,
#    3718 )
# -> 3720 return DataFrameRenderer(formatter).to_csv(
#    3721     path_or_buf,
#    3722     lineterminator=lineterminator,
#    3723     sep=sep,
#    3724     encoding=encoding,
#    3725     errors=errors,
#    3726     compression=compression,
#    3727     quoting=quoting,
#    3728     columns=columns,
#    3729     index_label=index_label,
#    3730     mode=mode,
#    3731     chunksize=chunksize,
#    3732     quotechar=quotechar,
#    3733     date_format=date_format,
#    3734     doublequote=doublequote,
#    3735     escapechar=escapechar,
#    3736     storage_options=storage_options,
#    3737 )
#
# File c:\users\beagg\appdata\local\programs\python\python38\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\users\beagg\appdata\local\programs\python\python38\lib\site-packages\pandas\io\formats\format.py:1189, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1168     created_buffer = False
#    1170 csv_formatter = CSVFormatter(
#    1171     path_or_buf=path_or_buf,
#    1172     lineterminator=lineterminator,
#    (...)
#    1187     formatter=self.fmt,
#    1188 )
# -> 1189 csv_formatter.save()
#    1191 if created_buffer:
#    1192     assert isinstance(path_or_buf, StringIO)
#
# File c:\users\beagg\appdata\local\programs\python\python38\lib\site-packages\pandas\io\formats\csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.lineterminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File c:\users\beagg\appdata\local\programs\python\python38\lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'artistas_procesados.csv'

# %%
eventos_fixed.to_csv('eventos_procesados.csv',encoding='utf-8')

# %%
productoras.to_csv('productoras_procesados.csv',encoding='utf-8')

# %%
recintos.to_csv('recintos_procesados.csv',encoding='utf-8')

# %%
entradas.to_csv('entradas_procesados.csv',encoding='utf-8')

# %%
entradas.to_csv('entradas_procesados.csv',encoding='utf-8')

# %%
# lugares.to_csv('lugares_procesados.csv',encoding='utf-8')

# %%
with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    print(entradas)
